# %% [markdown]
# <a href="https://colab.research.google.com/github/aslla77/practice-Python/blob/main/2nd/12_Logistic_Regression_Ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense
from tensorflow.keras.optimizers import SGD,Adam

# %%
filename='/content/drive/MyDrive/diabetes.csv'

load_data=np.loadtxt(filename,delimiter=',')
x_data=load_data[:,0:-1]
t_data=load_data[:,[-1]]

print(x_data.shape,t_data.shape)
# Out:
# (759, 8) (759, 1)

# %%
model=Sequential()

model.add(Dense(t_data.shape[1],input_shape=(x_data.shape[1],),activation='sigmoid'))

# %%
model.compile(optimizer=SGD(learning_rate=1e-2),loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 1)                 9
#
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist=model.fit(x_data,t_data,epochs=500,validation_split=0.2,verbose=2)
# Out:
# Epoch 1/500
# 19/19 - 1s - loss: 0.7079 - accuracy: 0.5189 - val_loss: 0.6982 - val_accuracy: 0.5461 - 870ms/epoch - 46ms/step
# Epoch 2/500
# 19/19 - 0s - loss: 0.6889 - accuracy: 0.5404 - val_loss: 0.6804 - val_accuracy: 0.5789 - 67ms/epoch - 4ms/step
# Epoch 3/500
# 19/19 - 0s - loss: 0.6732 - accuracy: 0.5634 - val_loss: 0.6655 - val_accuracy: 0.6053 - 65ms/epoch - 3ms/step
# Epoch 4/500
# 19/19 - 0s - loss: 0.6601 - accuracy: 0.5766 - val_loss: 0.6531 - val_accuracy: 0.5987 - 67ms/epoch - 4ms/step
# Epoch 5/500
# 19/19 - 0s - loss: 0.6491 - accuracy: 0.6046 - val_loss: 0.6427 - val_accuracy: 0.6184 - 74ms/epoch - 4ms/step
# Epoch 6/500
# 19/19 - 0s - loss: 0.6399 - accuracy: 0.6260 - val_loss: 0.6340 - val_accuracy: 0.6316 - 50ms/epoch - 3ms/step
# Epoch 7/500
# 19/19 - 0s - loss: 0.6323 - accuracy: 0.6326 - val_loss: 0.6267 - val_accuracy: 0.6250 - 56ms/epoch - 3ms/step
# Epoch 8/500
# ...

# %%
model.evaluate(x_data,t_data)
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4787 - accuracy: 0.7721
# [0.4787485897541046, 0.7720685005187988]

# %%
plt.title('Loss Trend')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.grid()

plt.plot(hist.history['loss'],label='train loss')
plt.plot(hist.history['val_loss'],label='validant loss')

plt.legend(loc='best')
plt.show()

# %%
plt.title('Accuracy Trend')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()

plt.plot(hist.history['accuracy'],label='train accuracy')
plt.plot(hist.history['val_accuracy'],label='validant accuracy')

plt.legend(loc='best')
plt.show()
